# %%
# Useful starting lines
# %matplotlib inline
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the data

# %%
import datetime
from helpers import *

height, weight, gender = load_data(sub_sample=False, add_outlier=False)
x, mean_x, std_x = standardize(height)
y, tx = build_model_data(x, weight)

# %%
y.shape, tx.shape
# Out:
# ((10000,), (10000, 2))

# %%
tx[:,0]
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %% [markdown]
# # 1 Computing the Cost Function

# %% [markdown]
# Fill in the `compute_loss` function below:
# <a id='compute_loss'></a>

# %%
def compute_loss(y, tx, w):
    """Calculate the loss.

    You can calculate the loss using mse or mae.
    """
    loss = (1/(2*y.shape[0])) * np.sum((y-w[0]*tx[:,0]-w[1]*tx[:,1])**2)
    #raise NotImplementedError
    return loss
w=[1,2]
compute_loss(y, tx, w)
# Out:
# 2694.4833658870843

# %%
def compute_loss(y, tx, w):
    """Calculate the loss.

    You can calculate the loss using mse or mae.
    """
    e = y - tx.dot(w)
    loss = e.T.dot(e)/(2*len(e))
    #raise NotImplementedError
    return loss
w=[1,2]
compute_loss(y, tx, w)
# Out:
# 2694.483365887083

# %% [markdown]
# # 2 Grid Search
#
# Fill in the function `grid_search()` below:

# %%
def grid_search(y, tx, w0, w1):
    """Algorithm for grid search."""
    losses = np.zeros((len(w0), len(w1)))
    for i, wi in enumerate(w0):
        for j, wj, in enumerate(w1):
            w = np.array([wi,wj])
            loss = compute_loss(y,tx,w)
            losses[i,j] = loss 
    return losses

#losses = grid_search(y, tx, w0, w1)

# %% [markdown]
# Let us play with the grid search demo now!

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=10)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=42.42448314678248, w0*=66.66666666666669, w1*=16.666666666666686, execution time=0.270 seconds

# %% [markdown]
# # 3 Gradient Descent

# %% [markdown]
# Again, please fill in the functions `compute_gradient` below:

# %%
def compute_gradient(y, tx, w):
    """Compute the gradient."""
    e = y - tx.dot(w)
    gradient = - tx.T.dot(e) / len(y)
    return gradient

# %%
w = [100,20]
compute_gradient(y,tx,w)
# The results gives us the steepest of the slope
# Out:
# array([26.706078  ,  6.52028757])

# %%
w = [50,10]
compute_gradient(y,tx,w)
# Out:
# array([-23.293922  ,  -3.47971243])

# %%
w = [73.29392200210519,13.479712434989048]
compute_gradient(y,tx,w)
# Out:
# array([ 1.59161573e-15, -9.37916411e-17])

# %% [markdown]
# Please fill in the functions `gradient_descent` below:

# %%
def gradient_descent(y, tx, initial_w, max_iters, gamma):
    """Gradient descent algorithm."""
    # Define parameters to store w and loss
    ws = [initial_w]
    losses = []
    w = initial_w
    for n_iter in range(max_iters):
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: compute gradient and loss
        # ***************************************************
        gradient = compute_gradient(y,tx,w)
        loss = compute_loss(y, tx, w)
        # ***************************************************
        # INSERT YOUR CODE HERE
        # TODO: update w by gradient
        # ***************************************************
        w = w - gamma*gradient
        # store w and loss
        ws.append(w)
        losses.append(loss)
        print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))

    return losses, ws

# %% [markdown]
# Test your gradient descent function through gradient descent demo shown below:

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=2792.236712759168, w0=51.30574540147363, w1=9.435798704492282
# Gradient Descent(1/49): loss=265.30246210896, w0=66.69746902191572, w1=12.266538315840002
# Gradient Descent(2/49): loss=37.87837955044117, w0=71.31498610804834, w1=13.11576019924433
# Gradient Descent(3/49): loss=17.41021212017447, w0=72.70024123388814, w1=13.370526764265632
# Gradient Descent(4/49): loss=15.568077051450455, w0=73.11581777164007, w1=13.446956733772023
# Gradient Descent(5/49): loss=15.402284895265298, w0=73.24049073296565, w1=13.469885724623941
# Gradient Descent(6/49): loss=15.38736360120863, w0=73.27789262136334, w1=13.476764421879516
# Gradient Descent(7/49): loss=15.386020684743533, w0=73.28911318788263, w1=13.478828031056189
# Gradient Descent(8/49): loss=15.38589982226167, w0=73.29247935783842, w1=13.47944711380919
# Gradient Descent(9/49): loss=15.385888944638301, w0=73.29348920882515, w1=13.47963283863509
# Gradient Descent(10/49): loss=15.3858879656522, w0=73.29379216412117, w1=13.479688556082861
# Gradient Descent(11/49): loss=15.385887877543452, w0=73.29388305070998, w1=13.479705271317192
# Gradient Descent(12/49): loss=15.385887869613667, w0=73.29391031668662, w1=13.479710285887492
# Gradient Descent(13/49): loss=15.385887868899983, w0=73.29391849647962, w1=13.479711790258582
# Gradient Descent(14/49): loss=15.385887868835754, w0=73.29392095041752, w1=13.479712241569908
# Gradient Descent(15/49): loss=15.38588786882997, w0=73.29392168659889, w1=13.479712376963306
# Gradient Descent(16/49): loss=15.385887868829453, w0=73.2939219074533, w1=13.479712417581325
# Gradient Descent(17/49): loss=15.385887868829403, w0=73.29392197370962, w1=13.479712429766732
# Gradient Descent(18/49): loss=15.385887868829398, w0=73.29392199358652, w1=13.479712433422353
# Gradient Descent(19/49): loss=15.385887868829398, w0=73.2939219995496, w1=13.47971243451904
# Gradient Descent(20/49): loss=15.3858878688294, w0=73.29392200133852, w1=13.479712434848047
# Gradient Descent(21/49): loss=15.3858878688294, w0=73.29392200187519, w1=13.479712434946748
# Gradient Descent(22/49): loss=15.3858878688294, w0=73.29392200203618, w1=13.479712434976358
# Gradient Descent(23/49): loss=15.385887868829403, w0=73.29392200208449, w1=13.479712434985242
# Gradient Descent(24/49): loss=15.3858878688294, w0=73.29392200209898, w1=13.479712434987906
# Gradient Descent(25/49): loss=15.385887868829398, w0=73.29392200210333, w1=13.479712434988706
# Gradient Descent(26/49): loss=15.3858878688294, w0=73.29392200210464, w1=13.479712434988945
# Gradient Descent(27/49): loss=15.385887868829398, w0=73.29392200210502, w1=13.479712434989018
# Gradient Descent(28/49): loss=15.3858878688294, w0=73.29392200210513, w1=13.47971243498904
# Gradient Descent(29/49): loss=15.385887868829398, w0=73.29392200210518, w1=13.479712434989047
# Gradient Descent(30/49): loss=15.385887868829403, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(31/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(32/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(33/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(34/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(35/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(36/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(37/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(38/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(39/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(40/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(41/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(42/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(43/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(44/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(45/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(46/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(47/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(48/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent(49/49): loss=15.3858878688294, w0=73.29392200210519, w1=13.479712434989048
# Gradient Descent: execution time=1.579 seconds

# %%
# Time Visualization
# %matplotlib widget
from ipywidgets import IntSlider, interact

def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)
#plot_figure(3)
interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# TODO play with step, gamma, .....
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# # 4 Stochastic gradient descent

# %%
def compute_stoch_gradient(y, tx, w):
    """Compute a stochastic gradient from just few examples n and their corresponding y_n labels."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: implement stochastic gradient computation.It's same as the gradient descent.
    # ***************************************************
    e = y - tx.dot(w)
    gradient = - tx.T.dot(e) / len(y)
    return gradient


def stochastic_gradient_descent(
        y, tx, initial_w, batch_size, max_iters, gamma):
    """Stochastic gradient descent algorithm."""
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: implement stochastic gradient descent.
    # ***************************************************
    ws = [initial_w]
    losses = []
    w = initial_w
    for y_batch, tx_batch in batch_iter(y, tx, batch_size):
        gradient = compute_gradient(y,tx,w)
        loss = compute_loss(y, tx, w)

        w = w - gamma*gradient
        # store w and loss
        ws.append(w)
        losses.append(loss)
        #print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
           #   bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
    return losses, ws

# %%
# from stochastic_gradient_descent import *

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7
batch_size = 1

# Initialization
w_initial = np.array([0, 0])

# Start SGD.
start_time = datetime.datetime.now()
sgd_losses, sgd_ws = stochastic_gradient_descent(
    y, tx, w_initial, batch_size, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("SGD: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# SGD: execution time=0.004 seconds

# %%
# Time Visualization
# %matplotlib widget
from ipywidgets import IntSlider, interact
def plot_figure(n_iter):
    fig = gradient_descent_visualization(
        sgd_losses, sgd_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# interactive(children=(IntSlider(value=1, description='n_iter', max=51, min=1), Output()), _dom_classes=('widge…
# <function __main__.plot_figure(n_iter)>

# %% [markdown]
# # 5 Effect of Outliers

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# # 6 Subgradient Descent

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# Modify the function `compute_loss(y, tx, w)` for the Mean Absolute Error cost function [here](#compute_loss)
